# %%
import numpy
import matplotlib.pyplot as plt

x:list = numpy.random.uniform(0.0, 5.0, 250)

plt.hist(x, 5)
plt.show()

# %%
import numpy
import matplotlib.pyplot as plt

x = numpy.random.uniform(0.0, 500.0, 10000)

plt.hist(x, 100)
plt.show()
